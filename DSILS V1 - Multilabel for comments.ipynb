# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import re

# %%
data = pd.read_csv(r'data\jigsaw-toxic-comment-classification-challenge\train.csv')
train, test = train_test_split(data, test_size=0.3, random_state=94)

# %%
#get the text data
X_train = train.loc[:,'comment_text']
X_test  = test.loc[:,'comment_text']

# %%
#get the y
y_train = train.loc[:,['obscene','insult','toxic','severe_toxic','identity_hate','threat']]
y_test = test.loc[:,['obscene','insult','toxic','severe_toxic','identity_hate','threat']]

# %%
y_train.describe()
# Out:
#              obscene         insult          toxic   severe_toxic  \
# count  111699.000000  111699.000000  111699.000000  111699.000000
# mean        0.053904       0.050224       0.096697       0.010188
# std         0.225829       0.218408       0.295547       0.100421
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        identity_hate         threat
# count  111699.000000  111699.000000
# mean        0.009042       0.002999
# std         0.094660       0.054682
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000

# %%
#cleaning the data
def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"\'scuse", " excuse ", text)
    text = re.sub('\W', ' ', text)
    text = re.sub('\s+', ' ', text)
    text = text.strip(' ')
    return text

# %%
X_train = X_train.map(lambda x : clean_text(x))
X_test = X_test.map(lambda x : clean_text(x))

# %%
X_train
# Out:
# 137114    then again you idiots screw up most of gaming ...
# 32115     country profiles hi i saw your notice on the c...
# 147937    johnny marr he was in the members section when...
# 52270     satanizer thanks for the censorship 66 55 141 100
# 75895     in an act of desperation rick has tried to del...
# 29279     where is the mention in your sources to the ba...
# 14498     point i have always made useful contributions ...
# 103185    contribs i cannot believe i forgot to sign i a...
# 91366     renault z e please do not create straw man arg...
# 12395     vincent lefèvre crap he insistently replaces s...
# 131260              awww that all yawns chumps 98 214 81 82
# 152171    different systems and different bills but enac...
# 120458    diffs with edit summary avoid manual sizing of...
# 96881     bot report found duplicate references in the l...
# 79297     attacks in please do not make personal attacks...
# 92168     reply remove incorrect libelous comment by med...
# ...

# %%
#import library for removing stop words
import spacy
spacy_nlp = spacy.load('en_core_web_sm')

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
Xtrain_token = [spacy_nlp(x) for x in X_train]
Xtest_token = [spacy_nlp(x) for x in X_test]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-042e9cde05dd> in <module>
# ----> 1 Xtrain_token = [spacy_nlp(x) for x in X_train]
#       2 Xtest_token = [spacy_nlp(x) for x in X_test]
#
# <ipython-input-33-042e9cde05dd> in <listcomp>(.0)
# ----> 1 Xtrain_token = [spacy_nlp(x) for x in X_train]
#       2 Xtest_token = [spacy_nlp(x) for x in X_test]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# ...

# %%
X_train_token
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-15e57356c11a> in <module>
# ----> 1 X_train.comment_text
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'comment_text'

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english'))

# %%
X_train_token = word_tokenize(X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-b082f31fb60a> in <module>
# ----> 1 X_train_token = word_tokenize(X_train)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     103     """
#     104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 105     return tokenizer.tokenize(text)
#     106
#     107
#
# ...

# %%
import preprocessingg as preproc

# %%
X_trainT = preproc.preprocess(X_train)
X_testT  = preproc.preprocess(X_test)
# Out:
# Starting preprocessing
# Step 0 : Importing libraries used.
# Step 1 : Tokenized done.
# Step 2 : Remove stop words done.
# Step 3 : Bigram analysis done.
# Preprocessing done.
# Starting preprocessing
# Step 0 : Importing libraries used.
# Step 1 : Tokenized done.
# Step 2 : Remove stop words done.
# Step 3 : Bigram analysis done.
# Preprocessing done.

# %%
X_trainT
# Out:
# [['idiots',
#   'screw',
#   'gaming',
#   'history',
#   'already',
#   'point',
#   'go',
#   'andhave',
#   'dreamcast',
#   'pioneered',
#   'bs',
#   'freaking',
#   'illusion',
#   'sad',
#   'media',
#   'uses',
#   'wikipedia',
#   'instead',
#   'reliable_sources',
#   'time',
#   'retarted',
#   'quality',
#   'control',
#   'user',
#   'indrian',
#   'already',
#   'tried',
#   'change',
#   'facts',
#   'bias',
#   'administration',
#   'seems',
#   'liking',
#   'bs'],
#  ['country',
#   'profiles',
#   'hi',
#   'saw',
#   'notice',
#   'community_portal',
#   'exactly',
#   'want',
#   'people',
#   'notice',
#   'clear'],
#  ['johnny',
#   'marr',
#   'members',
#   'section',
#   'worked',
#   'studio',
#   'week',
#   'unless',
#   'something',
#   'missed',
#   'think'],
#  ['satanizer', 'thanks', 'censorship'],
#  ['act',
#   'desperation',
#   'rick',
#   'tried',
#   'delete',
#   'report',
#   'also',
#   'reported',
#   'ani'],
#  ['mention',
#   'sources',
# ...
